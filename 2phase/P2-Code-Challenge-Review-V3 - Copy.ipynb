# %% [markdown]
# # Assessment Review

# %% [markdown]
# The topics covered will be:
#
# 1. SQL
# 2. Bayesian Statistics
# 3. Normal Distributions
# 4. Statistical Tests

# %%
# from src.call import call_on_students

# %% [markdown]
# ## Part 1: SQL

# %%
# Need to import pandas and sqlite3
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('data/Chinook_Sqlite.sqlite')

# %%
pd.read_sql(
    """
    SELECT *
    FROM Customer
    
    """, conn
)
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
pd.read_sql(
    """
    SELECT *
    FROM Invoice
    
    """, conn
)
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart         None
# 1                            Ullevålsveien 14        Oslo         None
# 2                             Grétrystraat 63    Brussels         None
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %% [markdown]
# ### Task 1: Write a query to return the customer IDs for every customer in Germany.

# %%
# call_on_students(1)
pd.read_sql(
    """
    SELECT CustomerID
    FROM Customer
    WHERE Country ='Germany'
    """, conn
)
# Out:
#    CustomerId
# 0           2
# 1          36
# 2          37
# 3          38

# %% [markdown]
# ### Task 2: Write a query to return the last names, email addresses and *billing* addresses of the customers who live in Canada.

# %%
# call_on_students(1)
pd.read_sql(
    """
    SELECT LastName, Email, Address
    FROM Customer
    WHERE Country ='Canada'
    """, conn
)
# Out:
#    LastName                   Email                 Address
# 0  Tremblay     ftremblay@gmail.com       1498 rue Bélanger
# 1   Philips      mphilips12@shaw.ca          8210 111 ST NW
# 2  Peterson     jenniferp@rogers.ca     700 W Pender Street
# 3     Brown        robbrown@shaw.ca  796 Dundas Street West
# 4   Francis     edfrancis@yachoo.ca        230 Elgin Street
# 5      Silk    marthasilk@gmail.com   194A Chain Lake Drive
# 6  Mitchell  aaronmitchell@yahoo.ca      696 Osborne Street
# 7  Sullivan  ellie.sullivan@shaw.ca          5112 48 Street

# %% [markdown]
# ### Task 3: Write a query to return the billing totals by country, in descending order of the totals.

# %%
# call_on_students(1)
pd.read_sql(
    """
    SELECT BillingCountry, SUM(Total) AS Country_Totals
    FROM Invoice
    Group BY BillingCountry
    ORDER BY Country_Totals desc
    """, conn
)
# Out:
#     BillingCountry  Country_Totals
# 0              USA          523.06
# 1           Canada          303.96
# 2           France          195.10
# 3           Brazil          190.10
# 4          Germany          156.48
# 5   United Kingdom          112.86
# 6   Czech Republic           90.24
# 7         Portugal           77.24
# 8            India           75.26
# 9            Chile           46.62
# 10         Ireland           45.62
# 11         Hungary           45.62
# 12         Austria           42.62
# 13         Finland           41.62
# 14     Netherlands           40.62
# 15          Norway           39.62
# 16          Sweden           38.62
# 17          Poland           37.62
# 18           Italy           37.62
# 19         Denmark           37.62
# 20       Australia           37.62
# 21       Argentina           37.62
# 22           Spain           37.62
# 23         Belgium           37.62

# %% [markdown]
# ### ***Task 4: Write a query to return the last names, email addresses, billing addresses, and most recent invoice dates for the customers whose most recent invoice is after Dec 31, 2011.

# %%
pd.read_sql(
    """
    SELECT c.LastName, c.Email, i.BillingAddress, MAX(i.InvoiceDate) AS RecentInvoiceDate
    FROM Customer AS c
    JOIN Invoice AS i 
        USING(CustomerId)
    WHERE i.InvoiceDate > '2011-12-31'
    GROUP BY c.LastName, c.Email, i.BillingAddress;
    """,conn)

# %%
pd.read_sql(
    """
    SELECT c.LastName, c.Email, i.BillingAddress, MAX(i.InvoiceDate) AS RecentInvoiceDate
    FROM Customer AS c
    JOIN Invoice AS i 
        USING(CustomerId)
    WHERE i.InvoiceDate IN(SELECT i.InvoiceDate
                            FROM Invoice AS i
                            WHERE i.InvoiceDate> '2011-12-31'
                            GROUP BY CustomerId
    );

    """,conn)
# Out:
#    LastName                 Email    BillingAddress    RecentInvoiceDate
# 0  O'Reilly  hughoreilly@apple.ie  3 Chatham Street  2013-08-02 00:00:00

# %%
# call_on_students(1)
pd.read_sql(
    """
    SELECT c.LastName, c.Email, I.BIllingAddress, I.InvoiceDate
    FROM INVOICE as I
    JOIN Customer as c
        USING(CustomerId)
    ORDER BY I
    """,conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: a GROUP BY clause is required before HAVING
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-93-654cbe382232> in <module>
#       1 # call_on_students(1)
# ----> 2 pd.read_sql(
#       3     """
#       4     SELECT *
#       5     FROM INVOICE as I
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# ...

# %% [markdown]
# ## Part 2: Bayesian Statistics

# %% [markdown]
# $$ P(A|B) = \dfrac{P(B|A)P(A)}{P(B)}$$

# %% [markdown]
# ### The Prompt:
# > In the second session of the 98th congress in 1984, a congressman voted 'No' on providing aid to El Salvador.
# >
# > Given that 60% of the congress were Democrats, 75% of whom voted 'No' for providing aid to El Salvador, and only 5% of Republicans voted 'No' to the proposal, what is the conditional probability that this individual is a Democrat?

# %% [markdown]
# ### Task 5: Calculate the probability

# %%
# call_on_students(1)

# %% [markdown]
# **1. Which probability are we trying to find?**
#
#    - Probability of individual is a democrat given that voted for proposal as NO

# %% [markdown]
# **2. Based on that, what other pieces do we need?**
#
#    - P(voted NO given democrat)
#    - P(Democrat)
#    - P(voted No)

# %% [markdown]
# **3. Result?**
#
#    -P(D|N) = P(N|D).P(D)/P(N)

# %%
(0.75*0.6)/((0.75*0.6)+(0.4*0.05))
# Out:
# 0.9574468085106382

# %% [markdown]
# ## Part 3: Normal Distributions

# %% [markdown]
# In this part, you will analyze hours of sleep for Freshman at a University. We know that the population distribution of hours of sleep for Freshman at the University is normally distributed with a mean of 6 and a standard deviation of 2.

# %% [markdown]
# ### Task 6: Create a numeric variable `z_eight` that contains the z-score for a Freshman that sleeps 8 hours

# %%
# call_on_students(1)

# %%
# Code here
z_eight = (8-6)/2
z_eight
# Out:
# 1.0

# %% [markdown]
# ### Task 7: Create a numeric variable `over_eight` containing the approximate proportion of Freshman who get more than 8 hours of sleep

# %%
# call_on_students(1)

# %%
from scipy import stats

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import pandas as pd
import numpy as np

# %%
# Code here
over_eight = stats.norm.sf(z_eight)
over_eight
# Out:
# 0.15865525393145707

# %% [markdown]
# ### Task 8: Calculate a 95% confidence interval for the amount of sleep for one Freshman who sleeps 7 times with a mean of 5 hours and a standard deviation of 0.5 hours

# %%
# call_on_students(1)

# %%
# Code here
x_bar = 5
std = 0.5
n = 7

stats.t.interval(alpha = 0.95,                        
                 df= n-1,                                  
                 loc = x_bar,                              
                 scale = std/np.sqrt(n))
# Out:
# (4.53757712628571, 5.46242287371429)

# %% [markdown]
# ### Task 9: Interpret the 95% Confidence Interval that you derived in the above question

# %%
# call_on_students(1)

# %% [markdown]
# Interpret:
#
# - If take 100 samples 95 of the population mean lies between the range of 4.53 to 5.46

# %% [markdown]
# ## Part 4: Statistical Testing
#
# Let's make some hypotheses about cars!

# %% [markdown]
# ### Task 10: Set Up

# %%
# call_on_students(1)

# %%
# Imports - need pandas and matplotlib
from scipy import stats

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import pandas as pd
import numpy as np

# %%
# Import the auto-mpg csv from the data folder
df = pd.read_csv('data/auto-mpg.csv')

# %%
# Check the head of our data
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
# Check the info on our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car name      392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
# Describe the data
There is no missing values. Only car name is an object. All other information are either float or int. Model year and car name should have assigned as object types

# %%
# Run this cell without changes to set up for the next set of questions

# Grabbing the median car weight
weight_median = df['weight'].median()

# Separating based on light cars and heavy cars
heavy_cars = df.loc[df['weight'] > weight_median].sample(n=100, random_state=42)
light_cars = df.loc[df['weight'] <= weight_median].sample(n=100, random_state=42)

# Plotting histograms for acceleration for both light and heavy cars
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.set_title('Sample of Heavy Cars')
ax1.set_xlabel('Acceleration')
ax1.set_ylabel('Frequency')
ax1.hist(heavy_cars['acceleration'], bins=12)

ax2.set_title('Sample of Light Cars')
ax2.set_xlabel('Acceleration')
ax2.set_ylabel('Frequency')
ax2.hist(light_cars['acceleration'], bins=12)
plt.show()

# %% [markdown]
# ### The Prompt:
#
# > Car manufacturers want to know if light cars accelerate faster than heavy cars.
#
# ### Task 11: Set up the null and alternative hypotheses for this test

# %%
# call_on_students(1)

# %% [markdown]
# **Null hypothesis:**
#
# - There is no acceleration difference between light cars and heavy cars
#
#
# **Alternative hypothesis:**
#
# - Light cars accelerate faster than heavy cars

# %% [markdown]
# ### Task 12: Describe your Type 1 and Type 2 errors in this context

# %%
# call_on_students(1)

# %% [markdown]
# **Type I Error:**
#
# - False positive. Where rejecting the null hypothesis where shouldn't have reject it. when there is no difference between acceleration rejecting the null hypotheis.
#
#
# **Type II Error:**
#
#
# - False negative. Where fail to reject the null hypothesis where should have reject it. when acceleration of lighter cars faster than heavy cars fail to reject the null hypotheis.
# -

# %% [markdown]
# ### Task 13: The Hypothesis Test!

# %% [markdown]
# ### 13a: Describe the type of test:

# %%
# call_on_students(1)

# %% [markdown]
# Description:
#
# - one sided two sample t test

# %% [markdown]
# ### 13b: Run the test, using alpha = .05 and assuming that the samples have equal variance

# %%
# call_on_students(1)

# %%
# Code here
sample1 = heavy_cars['acceleration']
sample2 = light_cars['acceleration']
stats.ttest_ind(sample1,sample2, equal_var=False)
# Out:
# Ttest_indResult(statistic=-5.00874014469676, pvalue=1.2412905689208302e-06)

# %% [markdown]
# ### 13c: Analyze your results: can you reject the null hypothesis?

# %%
# call_on_students(1)

# %% [markdown]
# Can you reject the null hypothesis?
#
# - at 5% significant level can reject null hypothesis and conclude that light weight vehicle acceleration is fater than heavy cars.
